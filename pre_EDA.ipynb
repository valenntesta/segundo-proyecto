# %%
import pandas as pd

# %%
Acc_vel_loc_sinrangos = pd.read_csv('Datasets/00 Accesos/Acc_vel_loc_sinrangos.csv', encoding='latin1')
Acc_vel_loc_sinrangos.head()
# Out:
#       Provincia     Partido          Localidad Link Indec  Otros  0,256 Mbps  \
# 0  BUENOS AIRES  25 de Mayo         25 de Mayo    6854100    NaN         NaN
# 1  BUENOS AIRES  25 de Mayo    Agustín Mosconi    6854010    NaN         NaN
# 2  BUENOS AIRES  25 de Mayo          Del Valle    6854020    NaN         NaN
# 3  BUENOS AIRES  25 de Mayo          Ernestina    6854030    NaN         NaN
# 4  BUENOS AIRES  25 de Mayo  Gobernador Ugarte    6854040    NaN         NaN
#
#    0,5 Mbps  0,512 Mbps  0,75 Mbps  1 Mbps  ...  680 Mbps  700 Mbps  800 Mbps  \
# 0       2.0         NaN       19.0     NaN  ...       NaN       NaN       NaN
# 1       NaN         NaN        NaN     NaN  ...       NaN       NaN       NaN
# 2       1.0         NaN        NaN     NaN  ...       NaN       NaN       NaN
# 3       NaN         NaN        NaN     NaN  ...       NaN       NaN       NaN
# 4       NaN         NaN        NaN     NaN  ...       NaN       NaN       NaN
#
# ...

# %%
Accesos_por_tecnologia = pd.read_csv('Datasets/00 Accesos/Accesos_por_tecnologia.csv', encoding='latin1')
Accesos_por_tecnologia.head()
# Out:
#     Año Trimestre        Provincia      ADSL  Cablemodem Fibra óptica  \
# 0  2024         1     Buenos Aires  203.297   2.790.663    1.799.013
# 1  2024         1  Capital Federal   70.108   1.177.475      203.756
# 2  2024         1        Catamarca    5.901      11.025       56.542
# 3  2024         1            Chaco   11.343      58.929       64.463
# 4  2024         1           Chubut   26.306      77.217       26.356
#
#    Wireless    Otros       Total
# 0   150.290  101.294  5.044.557
# 1     4.493   48.879  1.504.711
# 2     1.384   81.000     74.933
# 3     8.404   12.404    155.543
# 4    30.867    9.930    170.676

# %%
Accesos_por_velocidad = pd.read_csv('Datasets/00 Accesos/Accesos_por_velocidad.csv', encoding='latin1')
Accesos_por_velocidad.head()
# Out:
#     Año  Trimestre        Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps  \
# 0  2024          1     Buenos Aires          26.002               22.510
# 1  2024          1  Capital Federal         516.000                5.418
# 2  2024          1        Catamarca          71.000              176.000
# 3  2024          1            Chaco         236.000              416.000
# 4  2024          1           Chubut         111.000                1.083
#
#   + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps  \
# 0           221.185             233.225              241.778
# 1            29.753              51.415               37.369
# 2             2.872               3.424                4.204
# 3            14.156               9.044                5.533
# 4            43.828              31.885               23.024
#
#    + 20 Mbps - 30 Mbps  + 30 Mbps    OTROS      Total
# 0              106.418  4.068.292  125.147  5.044.557
# ...

# %%
Accesos_Tecnologia_Localidad = pd.read_csv('Datasets/00 Accesos/Accesos_Tecnologia_Localidad.csv', encoding='latin1')
Accesos_Tecnologia_Localidad.head()
# Out:
#       Provincia     Partido               Localidad Link Indec  ADSL   \
# 0  BUENOS AIRES  25 de Mayo              25 de Mayo    6854100   755
# 1  BUENOS AIRES  25 de Mayo               Del Valle    6854020   181
# 2  BUENOS AIRES  25 de Mayo       Gobernador Ugarte    6854040   -
# 3  BUENOS AIRES  25 de Mayo  Norberto de la Riestra    6854060   -
# 4  BUENOS AIRES  25 de Mayo        Lucas Monteverde    6854050   -
#
#    CABLEMODEM   DIAL UP   FIBRA OPTICA   OTROS   SATELITAL   WIMAX   \
# 0       4.600       -                2     -           742     -
# 1         -         -              -        10           1     -
# 2         -         -              -       -           -       -
# 3         782       -              496      16         -       -
# 4         -         -              -       -           -       -
#
#    WIRELESS   Total general
# 0       727           6.826
# 1       -               192
# 2       181             181
# 3       185           1.479
# ...

# %%
Penetracion_hogares = pd.read_csv('Datasets/01 Penetracion/Penetracion-hogares.csv', encoding='latin1')
Penetracion_hogares.head()
# Out:
#     Año   Trimestre          Provincia  Accesos por cada 100 hogares
# 0  2024            1      Buenos Aires                        81,10
# 1  2024            1   Capital Federal                       119,53
# 2  2024            1         Catamarca                        68,82
# 3  2024            1             Chaco                        46,70
# 4  2024            1            Chubut                        84,89

# %%
Penetracion_Poblacion = pd.read_csv('Datasets/01 Penetracion/Penetracion-Poblacion.csv', encoding='latin1')
Penetracion_Poblacion.head()
# Out:
#     Año   Trimestre          Provincia  Accesos por cada 100 hab
# 0  2024            1      Buenos Aires                    27,80
# 1  2024            1   Capital Federal                    48,78
# 2  2024            1         Catamarca                    17,50
# 3  2024            1             Chaco                    12,48
# 4  2024            1            Chubut                    26,02

# %%
Penetracion_totales = pd.read_csv('Datasets/01 Penetracion/Penetracion-totales.csv', encoding='latin1')
Penetracion_totales.head()
# Out:
#     Año  Trimestre Accesos por cada 100 hogares Accesos por cada 100 hab  \
# 0  2024          1                        78,89                    24,79
# 1  2023          4                        78,56                    24,66
# 2  2023          3                        77,84                    24,41
# 3  2023          2                        77,02                    24,14
# 4  2023          1                        77,20                    24,17
#
#          Periodo
# 0   Ene-Mar 2024
# 1   Oct-Dic 2023
# 2  Jul-Sept 2023
# 3   Abr-Jun 2023
# 4   Ene-Mar 2023

# %%
Internet_IngresosTotalesxTrimestre = pd.read_csv('Datasets/02 Totales/Internet_IngresosTotalesxTrimestre.csv', encoding='latin1')
Internet_IngresosTotalesxTrimestre.head()
# Out:
#     Año   Trimestre  Ingresos (miles de pesos)         Periodo
# 0  2024            1           280.419.124,08     Ene-Mar 2024
# 1  2023            4           167.376.014,80     Oct-Dic 2023
# 2  2023            3           133.106.593,41    Jul-Sept 2023
# 3  2023            2           118.060.280,28     Jun-Mar 2023
# 4  2033            1           104.134.992,81     Ene-Mar 2023

# %%
Totales_Accesos_por_tecnologia = pd.read_csv('Datasets/02 Totales/Totales_Accesos_por_tecnologia.csv', encoding='latin1')
Totales_Accesos_por_tecnologia.head()
# Out:
#     Año   Trimestre         ADSL   Cablemodem   Fibra óptica    Wireless   \
# 0  2024            1     774.475    5.986.957      4.015.101      598.682
# 1  2023            4     836.390    6.022.532      3.908.183      585.760
# 2  2023            3     897.895    6.018.832      3.708.718      581.436
# 3  2023            2   1.006.509    5.997.149      3.463.988      581.823
# 4  2023            1   1.204.417    6.002.582      3.243.411      576.647
#
#     Otros         Total          Periodo
# 0  257.941   11.633.156     Ene-Mar 2024
# 1  194.796   11.547.661     Oct-Dic 2023
# 2  200.027   11.406.908    Jul-Sept 2023
# 3  202.428   11.251.897     Abr-Jun 2023
# 4  214.838   11.241.895     Ene-Mar 2023

# %%
Totales_Accesos_por_velocidad = pd.read_csv('Datasets/02 Totales/Totales_Accesos_por_velocidad.csv', encoding='latin1')
Totales_Accesos_por_velocidad.head()
# Out:
#     Año  Trimestre  Hasta 512 kbps  Entre 512 Kbps y 1 Mbps  \
# 0  2024          1          28.801                   69.355
# 1  2023          4          29.708                   71.742
# 2  2023          3          30.274                   80.609
# 3  2023          2          30.827                   79.405
# 4  2023          1          31.437                   82.048
#
#   Entre 1 Mbps y 6 Mbps Entre 6 Mbps y 10 Mbps Entre 10 Mbps y 20 Mbps  \
# 0               866.152                950.930                 672.155
# 1               900.253                978.108                 697.232
# 2               945.608                998.725                 720.084
# 3               963.510              1.028.250                 734.125
# 4             1.001.553              1.060.321                 729.194
#
#   Entre 20 Mbps y 30 Mbps Más de 30 Mbps    OTROS       Total
# 0                 353.896      8.363.694  328.173  11.633.156
# ...

# %%
Totales_Dial_BAf = pd.read_csv('Datasets/02 Totales/Totales_Dial_BAf.csv', encoding='latin1')
Totales_Dial_BAf.head()
# Out:
#     Año   Trimestre  Banda ancha fija  Dial up        Total        Periodo
# 0  2024            1      11.621.363    11.793  11.633.156    Ene-Mar 2024
# 1  2023            4      11.535.868    11.793  11.547.661    Oct-Dic 2023
# 2  2023            3      11.395.115    11.793  11.406.908   Jul-Sept 2023
# 3  2023            2      11.239.781    12.116  11.251.897    Abr-Jun 2023
# 4  2023            1      11.229.459    12.436  11.241.895    Ene-Mar 2023

# %%
Totales_VMD = pd.read_csv('Datasets/02 Totales/Totales_VMD.csv', encoding='latin1')
Totales_VMD.head()
# Out:
#     Año  Trimestre Mbps (Media de bajada)    Trimestre.1
# 0  2024          1                 139,15   Ene-Mar 2024
# 1  2023          4                 139,04   Oct-Dic 2023
# 2  2023          3                 129,67  Jul-Sept 2023
# 3  2023          2                 123,95   Abr-Jun 2023
# 4  2023          1                 110,50   Ene-Mar 2023

# %%
Velocidad_por_provincia = pd.read_csv('Datasets/03 Velocidad/Velocidad_por_provincia.csv', encoding='latin1')
Velocidad_por_provincia.head()
# Out:
#     Año  Trimestre        Provincia Mbps (Media de bajada)
# 0  2024          1     Buenos Aires                 159,13
# 1  2024          1  Capital Federal                 229,94
# 2  2024          1        Catamarca                  91,45
# 3  2024          1            Chaco                 107,51
# 4  2024          1           Chubut                  20,50

# %%
Velocidad_Sin_Rangos = pd.read_csv('Datasets/03 Velocidad/Velocidad_Sin_Rangos.csv', encoding='latin1')
Velocidad_Sin_Rangos.head()
# Out:
#       Año  Trimestre        Provincia     Otros  0,256 Mbps  0,375 Mbps   \
# 0  2024.0        1.0     Buenos Aires   125.147         18          -
# 1  2024.0        1.0  Capital Federal       -           31          -
# 2  2024.0        1.0        Catamarca        70        -            -
# 3  2024.0        1.0            Chaco     3.816        -            -
# 4  2024.0        1.0           Chubut    16.640          8          -
#
#   0,625 Mbps  0,5 Mbps 0,512 Mbps 0,75 Mbps  ... 2048 Mbps 2529 Mbps  \
# 0       -       25.815       169     4.611   ...      -         -
# 1       -      451.000        34     1.307   ...      -         -
# 2       -       34.000        37       -     ...      -         -
# 3       -      234.000         2       -     ...      -         -
# 4       -       69.000        34       836   ...      -         -
#
#   3072 Mbps 4000 Mbps 5000 Mbps 5125 Mbps 6000 Mbps 7000 Mbps  8000 Mbps  \
# ...

# %%
Dial_BAf = pd.read_csv('Datasets/04 Otros/Dial-BAf.csv', encoding='latin1')
Dial_BAf.head()
# Out:
#     Año  Trimestre        Provincia Banda ancha fija  Dial up      Total
# 0  2024          1     Buenos Aires        5.038.657     5.90  5.044.557
# 1  2024          1  Capital Federal        1.502.661     2.05  1.504.711
# 2  2024          1        Catamarca           74.932     1.00     74.933
# 3  2024          1            Chaco          155.538     5.00    155.543
# 4  2024          1           Chubut          169.819   857.00    170.676

# %%
kpi_2 = pd.read_csv('kpi_2.csv', encoding='latin1')
kpi_2.head()
# Out:
#    AÃ±o  Trimestre  Hasta 512 kbps  Entre 512 Kbps y 1 Mbps  \
# 0  2024          1          28.801                   69.355
# 1  2023          4          29.708                   71.742
# 2  2023          3          30.274                   80.609
# 3  2023          2          30.827                   79.405
# 4  2023          1          31.437                   82.048
#
#   Entre 1 Mbps y 6 Mbps Entre 6 Mbps y 10 Mbps Entre 10 Mbps y 20 Mbps  \
# 0               866.152                950.930                 672.155
# 1               900.253                978.108                 697.232
# 2               945.608                998.725                 720.084
# 3               963.510              1.028.250                 734.125
# 4             1.001.553              1.060.321                 729.194
#
#   Entre 20 Mbps y 30 Mbps  Conexiones_30Mbps    OTROS       Total
# 0                 353.896          8363694.0  328.173  11.633.156
# ...
